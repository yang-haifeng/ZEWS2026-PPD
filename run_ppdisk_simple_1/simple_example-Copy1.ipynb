# %%
import os

# %%
os.system("radmc3d image stokes lambda 2.2 incl 45")
# Out:
#
# ...
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2020 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, register to
#                      the RADMC-3D forum:
#             http://radmc3d.ita.uni-heidelberg.de/phpbb/
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
# ...
#
#  Number of processors:           10
#  Number of threads in use:            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(17) to exactly pi/2...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

f = open("image.out")
f.readline()
npx, npy = [int(t) for t in f.readline().split()]
nlam = float(f.readline())
au = 1.49597871e13
dpx, dpy = [float(t)/au for t in f.readline().split()] # dpx, dpy in AU
f.readline()
data = np.loadtxt(f)
f.close()

I = data[:,0]
Q = data[:,1]
U = data[:,2]
V = data[:,3]

I.shape = npx, npy 
Q.shape = npx, npy 
U.shape = npx, npy 
V.shape = npx, npy

# %%
plt.imshow(I)

# %%
from matplotlib.colors import LogNorm
plt.imshow(I, norm=LogNorm())

# %%
plt.imshow(U)
plt.colorbar()

# %%
plt.imshow(data1)

# %%
npx, npy = 100, 100
x = (np.arange(npx) - npx//2 - ((npx+1)%2)*0.5)
y = (np.arange(npy) - npy//2 - ((npy+1)%2)*0.5)
XX,YY = np.meshgrid(x,y)

# %%
plt.imshow(data1*(XX**2+YY**2))

# %%
os.system("radmc3d image lambda 2.2 incl 45")
# Out:
#
# ...
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2020 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, register to
#                      the RADMC-3D forum:
#             http://radmc3d.ita.uni-heidelberg.de/phpbb/
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
# ...
#
#  Number of processors:           10
#  Number of threads in use:            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(17) to exactly pi/2...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
# ...

# %%
data = np.loadtxt("image.out", skiprows=6)
data.shape = 100, 100

# %%
plt.imshow(data, norm=LogNorm())

# %%
os.system("radmc3d image lambda 870 incl 45")
os.system("mv image.out image870.out")
# Out:
#
# ...
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2020 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, register to
#                      the RADMC-3D forum:
#             http://radmc3d.ita.uni-heidelberg.de/phpbb/
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
# ...
#
#  Number of processors:           10
#  Number of threads in use:            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(17) to exactly pi/2...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
# ...

# %%
data870 = np.loadtxt("image870.out", skiprows=6)
data870.shape = 100, 100

# %%
plt.imshow(data870, norm=LogNorm())

# %%
os.system("radmc3d image lambda 1300 incl 45")
os.system("mv image.out image1300.out")
# Out:
#
# ...
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2020 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, register to
#                      the RADMC-3D forum:
#             http://radmc3d.ita.uni-heidelberg.de/phpbb/
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
# ...
#
#  Number of processors:           10
#  Number of threads in use:            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(17) to exactly pi/2...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
# ...

# %%
data1300 = np.loadtxt("image1300.out", skiprows=6)
data1300.shape = 100, 100

# %%
plt.imshow(data1300, norm=LogNorm())

# %%
os.system("radmc3d image lambda 3100 incl 45")
os.system("mv image.out image3100.out")
# Out:
#
# ...
#       WELCOME TO RADMC-3D: A 3-D CONTINUUM AND LINE RT SOLVER
#
#                           VERSION 2.0
#
#                 (c) 2008-2020 Cornelis Dullemond
#
#        Please feel free to ask questions. Also please report
#         bugs and/or suspicious behavior without hestitation.
#       The reliability of this code depends on your vigilance!
#                     dullemond@uni-heidelberg.de
#
#    To keep up-to-date with bug-alarms and bugfixes, register to
#                      the RADMC-3D forum:
#             http://radmc3d.ita.uni-heidelberg.de/phpbb/
#
#               Please visit the RADMC-3D home page at
#   http://www.ita.uni-heidelberg.de/~dullemond/software/radmc-3d/
# ...
#
#  Number of processors:           10
#  Number of threads in use:            1
#  Reading global frequencies/wavelengths...
#  Reading grid file and prepare grid tree...
#     Adjusting theta(17) to exactly pi/2...
#  Reading star data...
#  Note: Please be aware that you treat the star(s) as
# ...

# %%
data3100 = np.loadtxt("image3100.out", skiprows=6)
data3100.shape = 100, 100

# %%
plt.imshow(data3100, norm=LogNorm())

# %%
alpha = np.log( data870/data1300 ) / np.log( 1300/870 )
# Out:
# /var/folders/n_/548f7yt50v998q6vfrw8vbzm0000gn/T/ipykernel_75959/2507928480.py:1: RuntimeWarning: invalid value encountered in divide
#   alpha = np.log( data870/data1300 ) / np.log( 1300/870 )

# %%
plt.imshow(alpha,cmap='turbo')
plt.colorbar()
